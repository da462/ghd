# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
resp = requests.get('https://groundhog-day.com/api/v1/groundhogs/punxsutawney-phil')

# %%
pd.DataFrame(resp.json()['groundhogs'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pd.DataFrame(resp.json()['groundhogs'])
#
# KeyError: 'groundhogs'

# %%
df = pd.read_csv('ghd.csv')#.dropna()
# df['Year'] = df['Year'].astype('datetime64[s]')
df = df.set_index('Year')
df
# Out:
#           Punxsutawney Phil  February Average Temperature  \
# Year
# 1886              No Record                           NaN
# 1887            Full Shadow                           NaN
# 1888            Full Shadow                           NaN
# 1889              No Record                           NaN
# 1890              No Shadow                           NaN
# ...                     ...                           ...
# 2013              No Shadow                         34.77
# 2014            Full Shadow                         32.13
# 2015            Full Shadow                         32.99
# 2016              No Shadow                         39.47
# 1901-2000               NaN                         33.82
#
#            February Average Temperature (Northeast)  \
# Year
# 1886                                            NaN
# 1887                                            NaN
# 1888                                            NaN
# ...

# %%
df.columns
# Out:
# Index(['Punxsutawney Phil', 'February Average Temperature',
#        'February Average Temperature (Northeast)',
#        'February Average Temperature (Midwest)',
#        'February Average Temperature (Pennsylvania)',
#        'March Average Temperature', 'March Average Temperature (Northeast)',
#        'March Average Temperature (Midwest)',
#        'March Average Temperature (Pennsylvania)'],
#       dtype='object')

# %%
df['Punxsutawney Phil'].value_counts()
# Out:
# Full Shadow       102
# No Shadow          16
# No Record          12
# Partial Shadow      1
# Name: Punxsutawney Phil, dtype: int64

# %%
df[df["Punxsutawney Phil"] == "Partial Shadow"]
# Out:
#      Punxsutawney Phil  February Average Temperature  \
# Year
# 1942    Partial Shadow                         30.74
#
#       February Average Temperature (Northeast)  \
# Year
# 1942                                      20.1
#
#       February Average Temperature (Midwest)  \
# Year
# 1942                                    29.7
#
#       February Average Temperature (Pennsylvania)  March Average Temperature  \
# Year
# 1942                                         23.2                      41.31
#
#       March Average Temperature (Northeast)  \
# Year
# 1942                                   35.7
#
#       March Average Temperature (Midwest)  \
# Year
# 1942                                 44.1
#
#       March Average Temperature (Pennsylvania)
# Year
# 1942                                      37.8
